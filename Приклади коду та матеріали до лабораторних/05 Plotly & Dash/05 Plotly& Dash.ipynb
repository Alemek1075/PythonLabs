# %% [markdown]
# # Plotly & Dash

# %% [markdown]
# [Загальний приклад](https://dash.plotly.com/layout)
#
# [Plotly H1 HTML Component](https://dash.plotly.com/dash-html-components/)
#
# [Plotly Paragraph Component](https://dash.plotly.com/dash-html-components/p)
#
# [Plotly HTML Div](https://dash.plotly.com/dash-html-components/div)
#
# [dcc.Graph](https://dash.plotly.com/dash-core-components/graph)
#
# [dcc input](https://dash.plotly.com/dash-core-components/input)
#
# [callback](https://dash.plotly.com/basic-callbacks)
