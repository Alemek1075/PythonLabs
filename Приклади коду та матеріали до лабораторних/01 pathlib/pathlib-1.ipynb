# %% [markdown]
# # pathlib.PurePath

# %% [raw]
# Зазвичай бібліотека сами вибирає потрібну версію класу (Windows або Posix).
# З метою демонстрації у деяких випадках версія класу підставлялась явно.
# !!! У реальних проєктах треба використовувати Path (або PurePath) без явного зазначення ОС.
#
# Шляхи в Posix-форматі PureWindowsPath обробляє більш кмітливо,
# ніж PurePosixPath вчиняє з шляхами у Windows-форматі.
#
# Більшість клітин цього блокноту виконувались під Ubuntu, деякі були виконані на іншому комп'ютері під Windows.
# Через це деякі об'єкти мають тип PurePosixPath, а деякі PureWindowsPath.

# %%
from pathlib import PurePath, PureWindowsPath, PurePosixPath

# %% [markdown]
# ## Створення об’єкта шляху

# %% [raw]
# Windows-samples

# %%
PurePath('c:\\QW\\1.txt')
# Out:
# PureWindowsPath('c:/QW/1.txt')

# %%
PurePath('c:/QW/1.txt')  # windows path in posix-format
# Out:
# PureWindowsPath('c:/QW/1.txt')

# %% [raw]
# POSIX-samples

# %%
PurePath('~/downloads/1.txt')
# Out:
# PurePosixPath('~/downloads/1.txt')

# %% [raw]
# мало б бути так, як далі (але, зрозуміло, що цей код не є кросплатформенним через використовувані шляхи)

# %%
PurePath('c:/QW/1.txt')
# Out:
# PurePosixPath('c:/QW/1.txt')

# %%
PurePath('~/downloads/1.txt')
# Out:
# PurePosixPath('~/downloads/1.txt')

# %% [raw]
# Universal samples

# %% [raw]
# проте з відносними шляхами проблем не виникає, якщо використовувати posix

# %%
PurePath('QW/1.txt')
# Out:
# PureWindowsPath('QW/1.txt')

# %%
PurePath('QW/1.txt')
# Out:
# PurePosixPath('QW/1.txt')

# %% [markdown]
# ### збираємо шлях з частин, роздільники в кінці опрацьовуються автоматично (крім кореневого)

# %% [raw]
# Windows-samples

# %%
PurePath('c:/', 'QW/2', '1.txt')
# Out:
# PureWindowsPath('c:/QW/2/1.txt')

# %%
PurePath('c:/', 'QW','2', '1.txt')
# Out:
# PureWindowsPath('c:/QW/2/1.txt')

# %%
PurePath('c:', 'QW', '2', '1.txt')  # це не те саме, що попереднє!
# Out:
# PureWindowsPath('c:QW/2/1.txt')

# %% [raw]
# Universal samples

# %%
PurePath('some_dir', '3.txt')
# Out:
# PureWindowsPath('some_dir/3.txt')

# %%
PurePath('some_dir', '3.txt')
# Out:
# PureWindowsPath('some_dir/3.txt')

# %%
PurePath('C1/C2', 'C1/C2/C3', '1.txt')
# Out:
# PureWindowsPath('C1/C2/C1/C2/C3/1.txt')

# %%
PurePath('C1/C2', 'C1/C2/C3', '1.txt')
# Out:
# PureWindowsPath('C1/C2/C1/C2/C3/1.txt')

# %% [raw]
# зміст отриманих шляхів під Unix та Windows буде різний, хоча в обох випадках шляхи є коректними:

# %%
PurePath('/', 'media', 'tatiana', 'DATA', '1.txt')
# Out:
# PurePosixPath('/media/tatiana/DATA/1.txt')

# %%
PurePath('/', 'media/', 'tataiana', 'DATA', '1.txt') # / у кінці не принципові (крім того, що задає корінь)
# Out:
# PurePosixPath('/media/tataiana/DATA/1.txt')

# %%
PurePath('/media/tatiana', 'DATA', '1.txt')
# Out:
# PurePosixPath('/media/tatiana/DATA/1.txt')

# %% [markdown]
# ### за наявності абсолютних шляхів перевага в останнього абсолютного

# %% [raw]
# POSIX-samples

# %%
PurePath('/media/tatiana', '/root/bin', 'B', '1.txt')
# Out:
# PurePosixPath('/root/bin/B/1.txt')

# %% [raw]
# Windows-samples

# %%
PurePath('c:/', 'd:/QW/2', 'B', '1.txt')
# Out:
# PureWindowsPath('d:/QW/2/B/1.txt')

# %% [markdown]
# ## Перетворення шляху на рядок

# %% [raw]
# Windows-samples

# %%
p = PurePath('f:/Python/Samples/1.txt')
p
# Out:
# PureWindowsPath('f:/Python/Samples/1.txt')

# %%
str(p)
# Out:
# 'f:\\Python\\Samples\\1.txt'

# %%
p.as_posix()
# Out:
# 'f:/Python/Samples/1.txt'

# %% [raw]
# POSIX-samples

# %%
p = PurePath('~/.ssh/config')
p
# Out:
# PurePosixPath('~/.ssh/config')

# %%
str(p)
# Out:
# '~/.ssh/config'

# %%
p.as_posix()
# Out:
# '~/.ssh/config'

# %% [markdown]
# ## Складові шляху

# %% [raw]
# Windows-samples

# %%
p = PurePath('f:/Python/Samples/1.txt')
p
# Out:
# PureWindowsPath('f:/Python/Samples/1.txt')

# %%
p.parts
# Out:
# ('f:\\', 'Python', 'Samples', '1.txt')

# %%
p.drive
# Out:
# 'f:'

# %%
p.root
# Out:
# '\\'

# %%
p.anchor
# Out:
# 'f:\\'

# %% [raw]
# POSIX-samples

# %%
p = PurePath('/media/tatiana/TMP/Projects/Streams-3-2/iosamples_3.py')
p
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/Streams-3-2/iosamples_3.py')

# %%
p.parts
# Out:
# ('/', 'media', 'tatiana', 'TMP', 'Projects', 'Streams-3-2', 'iosamples_3.py')

# %%
p.drive
# Out:
# ''

# %%
p.root
# Out:
# '/'

# %%
p.anchor
# Out:
# '/'

# %% [raw]
# Universal samples

# %%
p.parent
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/Streams-3-2')

# %%
for el in p.parents:
    print(el)
# Out:
# /media/tatiana/TMP/Projects/Streams-3-2
# /media/tatiana/TMP/Projects
# /media/tatiana/TMP
# /media/tatiana
# /media
# /

# %%
PurePath('1.txt').parent
# Out:
# PurePosixPath('.')

# %%
p.name   # An extension is a part of the name!!!
# Out:
# 'iosamples_3.py'

# %%
p1 = PurePath('1.ext1.ext2.ext3')
p1.name
# Out:
# '1.ext1.ext2.ext3'

# %%
p.suffix
# Out:
# '.py'

# %%
p1.suffix
# Out:
# '.ext3'

# %%
p.suffixes
# Out:
# ['.py']

# %%
p1.suffixes
# Out:
# ['.ext1', '.ext2', '.ext3']

# %%
p.stem
# Out:
# 'iosamples_3'

# %%
p1.stem
# Out:
# '1.ext1.ext2'

# %%
print(p, p.is_absolute())
# Out:
# /media/tatiana/TMP/Projects/Streams-3-2/iosamples_3.py True

# %%
print(p1, p1.is_absolute())
# Out:
# 1.ext1.ext2.ext3 False

# %% [markdown]
# ### Конструювання шляхів з частин

# %%
p
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/Streams-3-2/iosamples_3.py')

# %%
p.with_name('3.txt')
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/Streams-3-2/3.txt')

# %%
PurePath('/media/tatiana/TMP/Projects').with_name('3.txt')
# Out:
# PurePosixPath('/media/tatiana/TMP/3.txt')

# %%
PurePath('/media/tatiana/TMP/Projects').joinpath('1')
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/1')

# %%
PurePath('/media/tatiana/TMP/Projects').joinpath('1/')
# Out:
# PurePosixPath('/media/tatiana/TMP/Projects/1')
